# %% [markdown]
# # Using Scikit-Learn Neural Network Class to classify MNIST

# %% [markdown]
# # Sobre
#
# O MNIST de Yann LeCun é o conjunto de dados mais "usado" em Machine Learning, sendo muito utilizado como o problema "Hello World" em Machine Learning. É antigo, mas ainda muito útil. Mesmo o próprio Hinton permanece [Geoffrey Hinton's Capsule Network](https ://en.wikipedia.org/wiki/Capsule_neural_network) também usando MNIST como teste.
#
# Atualmente qualquer tutorial orientará o aluno a usar a biblioteca PyTorch para resolver o problema MNIST, mas vamos resolver o problema MNIST por código Python "puro", criando o algoritmo do zero ou usando a biblioteca convencional de aprendizado de máquina [Scikit-Learn](https://scikit-learn.org/stable/) `MLPClassifier`
#
# Para entender o que é o dataset, vale uma leitura em https://www.openml.org/d/554

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier

# %%
# load the data from https://www.openml.org/d/554
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)

# use the traditional train/test split
X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %% [markdown]
# Em seguida, vamos construir um modelo MLP de camada oculta única. Aqui vamos esperar que vocês modifiquem o modelo e os parâmetros de treinamento até que encontrem a melhor MLP possível:

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,),     # Aumentar neurônios na camada oculta
    max_iter=300,                  # Mais iterações para convergência
    alpha=1e-4,                    # Regularização (pode testar 1e-3, 1e-5)
    solver='adam',                 # Adam geralmente converge melhor que SGD
    verbose=10,
    random_state=1,
    learning_rate_init=0.01        # Learning rate menor para melhor convergência
)

# %%
# Inicia o treinamento:
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 2.13041191
# Iteration 2, loss = 0.69524585
# Iteration 3, loss = 0.56181491
# Iteration 4, loss = 0.50127808
# Iteration 5, loss = 0.49764529
# Iteration 6, loss = 0.52886122
# Iteration 7, loss = 0.57279155
# Iteration 8, loss = 0.54337719
# Iteration 9, loss = 0.61792531
# Iteration 10, loss = 0.62922291
# Iteration 11, loss = 0.61626332
# Iteration 12, loss = 0.73730859
# Iteration 13, loss = 0.83453376
# Iteration 14, loss = 0.97633858
# Iteration 15, loss = 0.99090139
# Iteration 16, loss = 0.80105692
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(learning_rate_init=0.01, max_iter=300, random_state=1, verbose=10)

# %% [markdown]
# A pergunta aqui é: qual o motivo de o loss (erro) das iterações estar tão alto?

# %%
X = X / 255.

# %%
# Dividindo os dados em conjuntos de treino e de testes:
X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %%
# Treinando o modelo:
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.23984533
# Iteration 2, loss = 0.10708621
# Iteration 3, loss = 0.08060561
# Iteration 4, loss = 0.06907630
# Iteration 5, loss = 0.05708547
# Iteration 6, loss = 0.05796808
# Iteration 7, loss = 0.05224926
# Iteration 8, loss = 0.04334914
# Iteration 9, loss = 0.04929266
# Iteration 10, loss = 0.05063968
# Iteration 11, loss = 0.04608476
# Iteration 12, loss = 0.03190001
# Iteration 13, loss = 0.04016018
# Iteration 14, loss = 0.03632486
# Iteration 15, loss = 0.03355598
# Iteration 16, loss = 0.03775678
# Iteration 17, loss = 0.04003640
# Iteration 18, loss = 0.03374978
# Iteration 19, loss = 0.04059287
# Iteration 20, loss = 0.02960935
# Iteration 21, loss = 0.03893365
# Iteration 22, loss = 0.03399309
# Iteration 23, loss = 0.04316086
# Iteration 24, loss = 0.03286277
# Iteration 25, loss = 0.03121165
# Iteration 26, loss = 0.03103176
# Iteration 27, loss = 0.03583187
# Iteration 28, loss = 0.03473597
# Iteration 29, loss = 0.03697911
# Iteration 30, loss = 0.03345465
# Iteration 31, loss = 0.03460048
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(learning_rate_init=0.01, max_iter=300, random_state=1, verbose=10)

# %%
print(f"Taxa de acerto no conjunto de treino: {mlp.score(X_train, y_train):.3f}")
print(f"E no conjunto de testes: {mlp.score(X_test, y_test):.3f}")
# Out:
# Taxa de acerto no conjunto de treino: 0.994
# E no conjunto de testes: 0.970

# %% [markdown]
# Como exercício, aplique PCA novamente nesse conjunto de dados, treine novamente os modelos e compare as diferenças entre performance nos conjuntos de treino e de testes em ambos os casos (ou seja, com e sem PCA).
#
# Depois de fazer isso, envie seu arquivo com o código no AVA.
